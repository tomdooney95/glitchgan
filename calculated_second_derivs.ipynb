# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from utils import calculate_derivative
# Out:
# 2025-02-25 10:30:53.764745: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-25 10:30:53.764818: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-25 10:30:53.769364: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-25 10:30:54.243867: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
data = np.load('data/glitch_GAN_samples.npy')
labels = np.load('data/glitch_GAN_labels.npy')
data.shape, labels.shape
# Out:
# ((60, 8192), (60, 5))

# %%
plt.figure(figsize=(9,5))
for i in range(9):
  plt.subplot(3, 3, i+1)
  plt.plot(data[-i])
  
plt.show()

# %%
data_deriv = calculate_derivative(np.arange(len(data[0]), dtype=np.float64), data)
data_deriv = np.asarray(data_deriv)
type(data_deriv), data_deriv.shape
# Out:
# (numpy.ndarray, (60, 8191))

# %%
import os
SAVE_DIR = 'data'
np.save(os.path.join(SAVE_DIR, "glitch_GAN_deriv_samples.npy"), data_deriv)
